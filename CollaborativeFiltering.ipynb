# %% [markdown]
# # Financial asset recommender - Collaborative filtering with LightGCN
#
# ## Introduction
#
# This notebook is aimed to serve as an introduction to the creation of a recommender that operates on a proprietary dataset of user-financial asset transactions in order to recommend assets that are similar to those that the user has invested in. It makes use of the Beta-RecSys library developed by the University of Glasgow, a comprehensive package used for training and evaluating powerful deep learning recommendation models. The library is available on GitHub at: https://github.com/beta-team/beta-recsys
#
# To get started, we install the Beta-RecSys framework. This can be done through pip - alternative installation methods are provided on the GitHub repository.

# %%
# !pip install beta-rec
# Out:
# Collecting beta-rec
#   Using cached beta_rec-0.3.2-py3-none-any.whl (178 kB)
# Requirement already satisfied: ray==1.0.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.0.1)
# Requirement already satisfied: tqdm>=4.45.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (4.62.3)
# Collecting gputil==1.4.0
#   Using cached GPUtil-1.4.0-py3-none-any.whl
# Requirement already satisfied: requests==2.24.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (2.24.0)
# Requirement already satisfied: torch>=1.7.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.10.1)
# Requirement already satisfied: py7zr~=0.6 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (0.17.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.21.2)
# Requirement already satisfied: aiohttp>=3.7.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (3.8.1)
# Requirement already satisfied: scipy>=1.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.7.2)
# Requirement already satisfied: tensorboardX>=2.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (2.4.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.0.1)
# Requirement already satisfied: py-cpuinfo~=5.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (5.0.0)
# Collecting mock==4.0.1
#   Using cached mock-4.0.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: tabulate~=0.8.7 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (0.8.9)
# Collecting munch==2.5.0
#   Using cached munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: rstcheck~=3.3.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (3.3.1)
# Collecting pandas==1.0.3
#   Using cached pandas-1.0.3-cp37-cp37m-win_amd64.whl (8.7 MB)
# Requirement already satisfied: psutil~=5.7.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (5.7.3)
# Collecting aiofiles~=0.4.0
#   Using cached aiofiles-0.4.0-py3-none-any.whl (9.2 kB)
# Collecting nest-asyncio~=1.3.3
#   Using cached nest_asyncio-1.3.3-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from munch==2.5.0->beta-rec) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from pandas==1.0.3->beta-rec) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from pandas==1.0.3->beta-rec) (2021.3)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.12.0)
# Requirement already satisfied: grpcio>=1.28.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (1.43.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.4.2)
# Requirement already satisfied: colorful in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.5.4)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (6.0)
# Requirement already satisfied: aiohttp-cors in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.7.0)
# Requirement already satisfied: py-spy>=0.2.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.3.11)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (1.0.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.4.4)
# Requirement already satisfied: gpustat in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.6.0)
# Requirement already satisfied: protobuf>=3.8.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.19.3)
# Requirement already satisfied: opencensus in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.8.0)
# Requirement already satisfied: google in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.0.0)
# Requirement already satisfied: redis<3.5.0,>=3.3.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.4.1)
# Requirement already satisfied: aioredis in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (2.0.1)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (8.0.3)
# Requirement already satisfied: jsonschema in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from requests==2.24.0->beta-rec) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from requests==2.24.0->beta-rec) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from requests==2.24.0->beta-rec) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from requests==2.24.0->beta-rec) (3.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (3.10.0.2)
# Requirement already satisfied: asynctest==0.13.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (2.0.7)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (1.2.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from click>=7.0->ray==1.0.1->beta-rec) (4.8.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (0.2.3)
# Requirement already satisfied: brotli>=1.0.9 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (1.0.9)
# Requirement already satisfied: pybcj>=0.5.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (0.5.0)
# Requirement already satisfied: texttable in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (1.6.4)
# Requirement already satisfied: pyppmd>=0.17.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (0.17.3)
# Requirement already satisfied: pycryptodomex>=3.6.6 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (3.13.0)
# Requirement already satisfied: pyzstd>=0.14.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (0.15.2)
# Requirement already satisfied: docutils>=0.7 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from rstcheck~=3.3.1->beta-rec) (0.18.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from scikit-learn>=0.22->beta-rec) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from scikit-learn>=0.22->beta-rec) (3.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google->ray==1.0.1->beta-rec) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beautifulsoup4->google->ray==1.0.1->beta-rec) (2.3.1)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from gpustat->ray==1.0.1->beta-rec) (7.352.0)
# Requirement already satisfied: blessings>=1.6 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from gpustat->ray==1.0.1->beta-rec) (1.7)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from importlib-metadata->click>=7.0->ray==1.0.1->beta-rec) (3.7.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from jsonschema->ray==1.0.1->beta-rec) (58.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from jsonschema->ray==1.0.1->beta-rec) (0.18.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from opencensus->ray==1.0.1->beta-rec) (2.4.0)
# Requirement already satisfied: opencensus-context==0.1.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from opencensus->ray==1.0.1->beta-rec) (0.1.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (1.54.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (2.3.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (0.4.8)
# Installing collected packages: pandas, nest-asyncio, munch, mock, gputil, aiofiles, beta-rec
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.1
#     Uninstalling nest-asyncio-1.5.1:
#       Successfully uninstalled nest-asyncio-1.5.1
# Successfully installed aiofiles-0.4.0 beta-rec-0.3.2 gputil-1.4.0 mock-4.0.1 munch-2.5.0 nest-asyncio-1.3.3 pandas-1.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# notebook 6.4.6 requires nest-asyncio>=1.5, but you have nest-asyncio 1.3.3 which is incompatible.
# jupyter-client 7.1.0 requires nest-asyncio>=1.5, but you have nest-asyncio 1.3.3 which is incompatible.
# Requirement already satisfied: beta-rec in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (0.3.2)
# Requirement already satisfied: ray==1.0.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.0.1)
# Requirement already satisfied: requests==2.24.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (2.24.0)
# Requirement already satisfied: scipy>=1.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.7.2)
# Requirement already satisfied: mock==4.0.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (4.0.1)
# Requirement already satisfied: torch>=1.7.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.10.1)
# Requirement already satisfied: tqdm>=4.45.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (4.62.3)
# Requirement already satisfied: psutil~=5.7.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (5.7.3)
# Requirement already satisfied: pandas==1.0.3 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.0.3)
# Requirement already satisfied: gputil==1.4.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.4.0)
# Requirement already satisfied: tabulate~=0.8.7 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (0.8.9)
# Requirement already satisfied: aiofiles~=0.4.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (0.4.0)
# Requirement already satisfied: tensorboardX>=2.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (2.4.1)
# Requirement already satisfied: nest-asyncio~=1.3.3 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.3.3)
# Requirement already satisfied: py7zr~=0.6 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (0.17.3)
# Requirement already satisfied: munch==2.5.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (2.5.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.21.2)
# Requirement already satisfied: py-cpuinfo~=5.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (5.0.0)
# Requirement already satisfied: rstcheck~=3.3.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (3.3.1)
# Requirement already satisfied: aiohttp>=3.7.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (3.8.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beta-rec) (1.0.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from munch==2.5.0->beta-rec) (1.16.0)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from pandas==1.0.3->beta-rec) (2021.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from pandas==1.0.3->beta-rec) (2.8.2)
# Requirement already satisfied: redis<3.5.0,>=3.3.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.4.1)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (6.0)
# Requirement already satisfied: py-spy>=0.2.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.3.11)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.19.3)
# Requirement already satisfied: gpustat in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.6.0)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (8.0.3)
# Requirement already satisfied: colorful in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.5.4)
# Requirement already satisfied: jsonschema in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.2.0)
# Requirement already satisfied: google in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.0.0)
# Requirement already satisfied: grpcio>=1.28.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (1.43.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.4.4)
# Requirement already satisfied: aioredis in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (2.0.1)
# Requirement already satisfied: aiohttp-cors in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.7.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (1.0.3)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (3.4.2)
# Requirement already satisfied: opencensus in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from ray==1.0.1->beta-rec) (0.8.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from requests==2.24.0->beta-rec) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from requests==2.24.0->beta-rec) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from requests==2.24.0->beta-rec) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from requests==2.24.0->beta-rec) (1.25.11)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (2.0.7)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (0.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (3.10.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from aiohttp>=3.7.4->beta-rec) (6.0.1)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from click>=7.0->ray==1.0.1->beta-rec) (4.8.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (0.2.3)
# Requirement already satisfied: pybcj>=0.5.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (0.5.0)
# Requirement already satisfied: pyppmd>=0.17.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (0.17.3)
# Requirement already satisfied: texttable in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (1.6.4)
# Requirement already satisfied: brotli>=1.0.9 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (1.0.9)
# Requirement already satisfied: pycryptodomex>=3.6.6 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (3.13.0)
# Requirement already satisfied: pyzstd>=0.14.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from py7zr~=0.6->beta-rec) (0.15.2)
# Requirement already satisfied: docutils>=0.7 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from rstcheck~=3.3.1->beta-rec) (0.18.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from scikit-learn>=0.22->beta-rec) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from scikit-learn>=0.22->beta-rec) (3.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google->ray==1.0.1->beta-rec) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from beautifulsoup4->google->ray==1.0.1->beta-rec) (2.3.1)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from gpustat->ray==1.0.1->beta-rec) (7.352.0)
# Requirement already satisfied: blessings>=1.6 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from gpustat->ray==1.0.1->beta-rec) (1.7)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from importlib-metadata->click>=7.0->ray==1.0.1->beta-rec) (3.7.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from jsonschema->ray==1.0.1->beta-rec) (58.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from jsonschema->ray==1.0.1->beta-rec) (0.18.0)
# Requirement already satisfied: opencensus-context==0.1.2 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from opencensus->ray==1.0.1->beta-rec) (0.1.2)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from opencensus->ray==1.0.1->beta-rec) (2.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (1.54.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (2.3.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (4.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\envs\kaggle-news\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.0.1->beta-rec) (0.4.8)

# %% [markdown]
# ## Dataset setup
#
# We use a proprietary dataset of investment transactions provided by the National Bank of Greece. This can be downloaded through the Infinitech Marketplace.
#
# Beta-RecSys supports a range of well-known interaction datasets used for recommendation models. However, this dataset being proprietary and not for public distribution means we will have to custom load its interactions into a format usable by the library. For this we then create a dataset object from this raw data, which can be processed as interactions by Beta-RecSys.

# %%
import sys, os, beta_rec
import pandas as pd
import numpy as np
from functools import partial

np_load_old = partial(np.load)
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)

# %%
from beta_rec.data import BaseData
from beta_rec.datasets.dataset_base import DatasetBase
from beta_rec.utils.constants import (
    DEFAULT_ITEM_COL,
    DEFAULT_RATING_COL,
    DEFAULT_TIMESTAMP_COL,
    DEFAULT_USER_COL,
)

# %%
data = pd.read_csv(
            'C:\\Users\\Javier\\PycharmProjects\\pythonProject\\dataset\\nbg_instruments_large_v3.csv',
            skiprows=[0],
            engine="python",
            names=[
                DEFAULT_USER_COL,
                DEFAULT_ITEM_COL,
                DEFAULT_RATING_COL,
                DEFAULT_TIMESTAMP_COL,
            ],
        )
data
# Out:
#                    col_user  col_item  col_rating col_timestamp
# 0      -1000399803742468017     12541         1.0    2018-05-09
# 1      -1000476326435445839     11907         1.0    2018-02-01
# 2      -1000476326435445839     13233         1.0    2018-10-12
# 3      -1000476326435445839     11907         1.0    2018-10-12
# 4      -1000570356359468369     12917         1.0    2018-07-18
# ...                     ...       ...         ...           ...
# 312999   998868334061509693        89         1.0    2021-05-07
# 313000   998868334061509693       268         1.0    2021-05-07
# 313001   998987671268040482     12885         1.0    2021-02-09
# 313002   998987671268040482     12885         1.0    2021-02-15
# 313003   999456452282545623     17605         1.0    2021-04-16
#
# [313004 rows x 4 columns]

# %%
mapping = dict()
for index, row in data.iterrows():
    uid = row[DEFAULT_USER_COL]
    if not uid in mapping:
        mapping[uid] = mapping.__len__()

# %%
f = open('C:\\Users\\Javier\\PycharmProjects\\pythonProject\\dataset\\map.csv','w')
f.write("ID,SERIALIZED_ID")
for key in mapping.keys():
    f.write("\n" + str(key) + "\t" + str(mapping[key]))
f.close()

# %%
f = open('C:\\Users\\Javier\\PycharmProjects\\pythonProject\\dataset\\cleaned.csv','w')
f.write(DEFAULT_USER_COL + ',' + DEFAULT_ITEM_COL + ',' + DEFAULT_RATING_COL + ',' + DEFAULT_TIMESTAMP_COL)
for index, row in data.iterrows():
    uid = mapping[row[DEFAULT_USER_COL]]
    f.write("\n" + str(uid) + "," + str(row[DEFAULT_ITEM_COL]) + "," + str(row[DEFAULT_RATING_COL]) + "," + str(row[DEFAULT_TIMESTAMP_COL]))
f.close()

# %%
class NBGSampleInstTrans(DatasetBase):
    """NBGSample Instruments Transactions Dataset."""

    def __init__(self, dataset_name="nbg_marketplace_cf_1", min_u_c=0, min_i_c=0, root_dir=None):
        """Init NBGSampleInstTrans Class."""
        super().__init__(
            dataset_name=dataset_name,
            min_u_c=min_u_c,
            min_i_c=min_i_c,
            root_dir=root_dir,
        )

    def preprocess(self):
        """Preprocess the raw file.

        Preprocess the file, convert it to a dataframe consisting of the user-item
        interactions and save it in the processed directory.
        """
        file_name = 'C:\\Users\\Javier\\PycharmProjects\\pythonProject\\dataset\\cleaned.csv'

        data = pd.read_csv(
            file_name,
            skiprows=[0],
            engine="python",
            names=[
                DEFAULT_USER_COL,
                DEFAULT_ITEM_COL,
                DEFAULT_RATING_COL,
                DEFAULT_TIMESTAMP_COL,
            ],
        )
        data[DEFAULT_TIMESTAMP_COL] =  pd.to_datetime(data[DEFAULT_TIMESTAMP_COL], format='%Y-%m-%d')

        self.save_dataframe_as_npz(
            #
            data,
           os.path.join(self.processed_path, f"{self.dataset_name}_interaction.npz"),
        )

        return os.path.join(self.processed_path, f"{self.dataset_name}_interaction.npz"), data

nbgdata = NBGSampleInstTrans()
result, data = nbgdata.preprocess()

# %%
result
# Out:
# 'C:\\Users\\Javier\\AppData\\Roaming\\Python\\Python38\\site-packages\\datasets\\nbg_marketplace_cf_1\\processed\\nbg_marketplace_cf_1_interaction.npz'

# %%
data
# Out:
#         col_user  col_item  col_rating col_timestamp
# 0              0     12541         1.0    2018-05-09
# 1              1     11907         1.0    2018-02-01
# 2              1     13233         1.0    2018-10-12
# 3              1     11907         1.0    2018-10-12
# 4              2     12917         1.0    2018-07-18
# ...          ...       ...         ...           ...
# 312999     32904        89         1.0    2021-05-07
# 313000     32904       268         1.0    2021-05-07
# 313001     32905     12885         1.0    2021-02-09
# 313002     32905     12885         1.0    2021-02-15
# 313003     25586     17605         1.0    2021-04-16
#
# [313004 rows x 4 columns]

# %% [markdown]
# ## Model configuration
#
# Recommender models such as this one have a vast range of adjustable parameters for saving intermediate and output files, as well as for optimizing performance. We create a configuration file that can be fed into the model that contains these key parameters and serves as an easily reusable way to not only create further models, but also to change model parameters without much hassle.

# %%
config_file = {
    "config_file":"C:\\Users\\Javier\\Documents\\glasgow\\Infinitech-FAR-CollaborativeFiltering\\configs\\lightgcn.json"
}

# %% [markdown]
# ## Data splitting
#
# We then perform a temporal split on the data, through the data object we just created. Beta-RecSys provides methods to split data in several different ways, such as leave-one-out, random, and several types of basket splits. A temporal data split splits the data into training, testing, and validation sets on the basis of the timestamps associated with each data point, where earlier data points are used for training and later ones for validation and testing, in order to simulate a more real-world setting where future trends are learned from past events. This is suitable for our current data, where investment transactions can change depending on temporal factors. However, if needed, one can also try out other splitting strategies.
#
# The below cell displays the output of data splitting.

# %%
split_dataset = nbgdata.load_temporal_split(n_test=1, n_negative=100)
new_data =  BaseData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 214521     | 214521     | 214521       | 214521          |
# | nunique | 10894      | 926        | 2            | 693             |
# +---------+------------+------------+--------------+-----------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 531566     | 531566     | 531566       | 531566          |
# | nunique | 5150       | 938        | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 528249     | 528249     | 528249       | 528249          |
# | nunique | 5119       | 938        | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 518293     | 518293     | 518293       | 518293          |
# | nunique | 5036       | 926        | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 520353     | 520353     | 520353       | 520353          |
# | nunique | 5055       | 926        | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table

# %% [markdown]
# ## Model training
#
# Collaborative filtering is a type of recommendation approach which uses user-item interactions to recommend items that the user might be interested in, based on the habits of other similar users. We choose a LightGCN recommendation model (available here: https://arxiv.org/abs/2002.02126), which is an improvement on the Neural Graph Collaborative Filtering model that leverages the most essential component of the graph structure - the neighbourhood aggregation, for collaborative filtering. This is trained with the temporally split data we just constructed.

# %%
from beta_rec.recommenders import MatrixFactorization, NGCF, NeuCF, LightGCN
engine = LightGCN(config_file)
engine.train(new_data)
print ('Model training complete')
# Out:
# loading config file C:\Users\Javier\Documents\glasgow\Infinitech-FAR-CollaborativeFiltering\configs\lightgcn.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +--------+----------+
# | keys   | values   |
# |--------+----------|
# +--------+----------+
# --------------------------------------------------------------------------------
# logs will save in file: C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\logs/lightgcn_default_20220127_180546_qdsifk .stdout.log .stderr.log
# 2022-01-27 18:05:48 [INFO]-Python version: 3.8.10 (tags/v3.8.10:3d8993a, May  3 2021, 11:48:03) [MSC v.1928 64 bit (AMD64)]
# 2022-01-27 18:05:48 [INFO]-pytorch version: 1.10.1+cu113
# 2022-01-27 18:05:48 [INFO]-The intermediate running statuses will be reported in folder: C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\runs/lightgcn_default_20220127_180546_qdsifk
# 2022-01-27 18:05:48 [INFO]-Model checkpoint will save in file: C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\checkpoints/lightgcn_default_20220127_180546_qdsifk
# 2022-01-27 18:05:48 [INFO]-Performance result will save in file: C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\results/lightgcn_result.csv
# 2022-01-27 18:05:48 [INFO]---------------------------------------------------------------------------------
# 2022-01-27 18:05:48 [INFO]-System configs
# 2022-01-27 18:05:48 [INFO]-
# +----+----------------+----------------------------------------------------------------------------------------------------------------------------+
# |    | keys           | values                                                                                                                     |
# |----+----------------+----------------------------------------------------------------------------------------------------------------------------|
# |  0 | root_dir       | C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default                                                     |
# |  1 | log_dir        | logs/                                                                                                                      |
# |  2 | result_dir     | results/                                                                                                                   |
# |  3 | process_dir    | C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\processes/                                          |
# |  4 | checkpoint_dir | checkpoints/                                                                                                               |
# |  5 | dataset_dir    | datasets/                                                                                                                  |
# |  6 | run_dir        | C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\runs/lightgcn_default_20220127_180546_qdsifk        |
# |  7 | tune_dir       | C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\tune_results/                                       |
# |  8 | device         | gpu                                                                                                                        |
# |  9 | seed           | 2020                                                                                                                       |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                                                                     |
# | 11 | k              | [5, 10, 20]                                                                                                                |
# | 12 | valid_metric   | ndcg                                                                                                                       |
# | 13 | valid_k        | 10                                                                                                                         |
# | 14 | result_file    | C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\results/lightgcn_result.csv                         |
# | 15 | save_mode      | average                                                                                                                    |
# | 16 | model_run_id   | lightgcn_default_20220127_180546_qdsifk                                                                                    |
# | 17 | log_file       | C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\logs/lightgcn_default_20220127_180546_qdsifk        |
# | 18 | model_save_dir | C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\checkpoints/lightgcn_default_20220127_180546_qdsifk |
# +----+----------------+----------------------------------------------------------------------------------------------------------------------------
# 2022-01-27 18:05:48 [INFO]-
# 2022-01-27 18:05:48 [INFO]---------------------------------------------------------------------------------
# 2022-01-27 18:05:48 [INFO]-Get a gpu with the most available memory : 0
# 2022-01-27 18:05:48 [INFO]-Initializing test engine ...
# 2022-01-27 18:05:48 [INFO]-Get a gpu with the most available memory : 0
# 2022-01-27 18:05:48 [ERROR]-
# C:\Users\Javier\AppData\Roaming\Python\Python38\site-packages\beta_rec\data\deprecated_data_base.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings[DEFAULT_RATING_COL][ratings[DEFAULT_RATING_COL] > 0] = 1.0
# 2022-01-27 18:05:50 [INFO]-C:\Users\Javier\PycharmProjects\pythonProject\IPythonNotebooks\default\processes/nbg_marketplace_cf_1/ngcf_nbg_marketplace_cf_1_temporal
# 2022-01-27 18:05:56 [INFO]-already create adjacency matrix (11820, 11820)
# 2022-01-27 18:05:56 [INFO]-generate single-normalized adjacency matrix.
# 2022-01-27 18:05:57 [INFO]-generate single-normalized adjacency matrix.
# 2022-01-27 18:05:57 [INFO]-already normalize adjacency matrix
# 2022-01-27 18:05:57 [INFO]-Setting device for torch_engine cuda:0
# 2022-01-27 18:05:57 [INFO]-
# LightGCN(
#   (user_embedding): Embedding(10894, 64)
#   (item_embedding): Embedding(926, 64)
#
# 2022-01-27 18:05:57 [INFO]-
# 2022-01-27 18:06:30 [INFO]-Making PairwiseNegativeDataset of length 214521
#   0%|                                                                                                                                                                                                                                                | 0/5 [00:00<?, ?it/s]Epoch 0 starts !
# 2022-01-27 18:06:30 [INFO]---------------------------------------------------------------------------------
# 2022-01-27 18:06:48 [INFO]-[Training Epoch 0], Loss 0.04640021547675133
#  20%|##############################################4                                                                                                                                                                                         | 1/5 [00:18<01:13, 18.45s/it]Epoch 1 starts !
# 2022-01-27 18:06:48 [INFO]---------------------------------------------------------------------------------
# 2022-01-27 18:07:17 [ERROR]-Exception in thread Thread-22:
# 2022-01-27 18:07:17 [ERROR]-Traceback (most recent call last):
# 2022-01-27 18:07:17 [ERROR]-  File "C:\Users\Javier\AppData\Local\Programs\Python\Python38\lib\threading.py", line 932, in _bootstrap_inner
# 2022-01-27 18:07:17 [ERROR]-    self.run()
# 2022-01-27 18:07:17 [ERROR]-  File "C:\Users\Javier\AppData\Local\Programs\Python\Python38\lib\threading.py", line 870, in run
# 2022-01-27 18:07:17 [ERROR]-    self._target(*self._args, **self._kwargs)
# 2022-01-27 18:07:17 [ERROR]-  File "C:\Users\Javier\AppData\Roaming\Python\Python38\site-packages\beta_rec\utils\common_util.py", line 232, in wrapper
# 2022-01-27 18:07:17 [ERROR]-    result = method(*args, **kw)
# 2022-01-27 18:07:17 [ERROR]-  File "C:\Users\Javier\AppData\Roaming\Python\Python38\site-packages\beta_rec\core\eval_engine.py", line 112, in train_eval_worker
# 2022-01-27 18:07:17 [ERROR]-    testEngine.expose_performance(valid_result, test_result)
# 2022-01-27 18:07:17 [ERROR]-AttributeError: 'EvalEngine' object has no attribute 'expose_performance'
# 2022-01-27 18:07:32 [INFO]-[Training Epoch 1], Loss 0.010593081824481487
#  40%|############################################################################################8                                                                                                                                           | 2/5 [01:02<01:40, 33.42s/it]Epoch 2 starts !
# 2022-01-27 18:07:32 [INFO]---------------------------------------------------------------------------------
# 2022-01-27 18:08:15 [INFO]-[Training Epoch 2], Loss 0.013884486630558968
#  60%|###########################################################################################################################################2                                                                                            | 3/5 [01:45<01:15, 37.65s/it]Epoch 3 starts !
# 2022-01-27 18:08:15 [INFO]---------------------------------------------------------------------------------
# 2022-01-27 18:09:13 [INFO]-[Training Epoch 3], Loss 0.025989286601543427
#  80%|#########################################################################################################################################################################################6                                              | 4/5 [02:43<00:45, 45.83s/it]Epoch 4 starts !
# 2022-01-27 18:09:13 [INFO]---------------------------------------------------------------------------------
# 2022-01-27 18:10:02 [INFO]-[Training Epoch 4], Loss 0.004564984701573849
# 100%|########################################################################################################################################################################################################################################| 5/5 [03:31<00:00, 42.36s/it]
# 2022-01-27 18:10:02 [INFO]-Program running time:244 seconds
# 2022-01-27 18:10:02 [INFO]-Model training complete

# %% [markdown]
# ## Obtaining recommendations
# Once we have trained the model, it is possible to predict the value of the different financial assets for the different users and rank them. Here, we show an example for user 0.

# %%
data[DEFAULT_USER_COL].unique()

# %% [markdown]
# ## Evaluation
#
# Beta-RecSys provides several inbuilt metrics for the evaluation of the performance of collaborative filtering recommenders. These can be specified in the configuration file, along with their ranges i.e. over how many predictions in the ranking these metrics are calculated. For our purposes we will use four key metrics commonly used to evaluate recommenders. These are:
#
# 1. <b>Normalized discounted cumulative gain (NDCG)</b>: This is a measure of ranking quality normalized across predictions, and calculates the performance of the recommender on the basis that highly relevant items should be recommended at higher ranks, as they are more useful as recommendations than other, less relevant items. It is the ratio of the discounted cumulative gain (DCG) and the idealized DCG. DCG is represented below
#
# \begin{equation}
# \text{DCG} = \sum_{i=1}^N \frac{rel_{i}}{\log_2 (i+1)}
# \end{equation}
#
# \begin{equation}
# \text{NDCG @ position p} = \frac{DCG_{p}}{IDCG_{p}}
# \end{equation}
#
#
# 2. <b>Precision</b>: This commonly used metric refers to the number of true positive, or relevant instances among retrieved items.
#
# \begin{equation}
# \text{Precision} = \frac{True \ Positives}{True \ Positives \ + \ False \ Positives}
# \end{equation}
#
# 3. <b>Recall</b>: Also referred to as sensitivity, this refers to the fraction of all relevant instances that were retrieved.
#
# \begin{equation}
# \text{Recall} = \frac{True \ Positives}{True \ Positives \ + \ False \ Negatives}
# \end{equation}
#
# 4. <b>Mean average precision (MAP)</b>: The mean average precision of a recommender is a metric that summarizes the precision-recall curve into a metric that represents the area under this curve and therefore is representative of the average of all precisions. MAP is the average of the AP value described below.
#
# \begin{equation}
# \text{Average Precision} = \sum_n (R_n - R_{n-1}) P_n
# \end{equation}
#
# These metrics are calculated across four ranges: 1, 3, 5 and 10 queries respectively. Beta-RecSys automatically calculates this set of metrics across the predictions for the ranges specified in the configuration file upon testing the model.

# %%
engine.config["save_mode"] = "average"
temporal_result = engine.test(new_data.test[0])
print ('Model testing complete')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [13], in <module>
#       1 engine.config["save_mode"] = "average"
# ----> 2 temporal_result = engine.test(new_data.test[0])
#       3 print ('Model testing complete')
#
# File ~\AppData\Roaming\Python\Python38\site-packages\beta_rec\core\recommender.py:43, in Recommender.test(self, test_df)
#      33 def test(self, test_df):
#      34     """Score and Evaluate for a dataframe data.
#      35
#      36     Args:
#    (...)
#      41
#      42     """
# ---> 43     result = self.eval_engine.test_eval(test_df, self.engine.model)
#      44     return result
#
# File ~\AppData\Roaming\Python\Python38\site-packages\beta_rec\utils\common_util.py:232, in timeit.<locals>.wrapper(*args, **kw)
#     229 @wraps(method)
#     230 def wrapper(*args, **kw):
#     231     ts = time.time()
# --> 232     result = method(*args, **kw)
#     233     te = time.time()
#     234     if "log_time" in kw:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\beta_rec\core\eval_engine.py:597, in EvalEngine.test_eval(self, test_df_list, model)
#     593     with concurrent.futures.ThreadPoolExecutor() as executor:
#     594         future = executor.submit(
#     595             test_eval_worker, self, test_data_df, test_pred
#     596         )
# --> 597         return_value = future.result()
#     598         return_value_list.append(return_value)
#     599 return return_value_list
#
# File ~\AppData\Local\Programs\Python\Python38\lib\concurrent\futures\_base.py:444, in Future.result(self, timeout)
#     442     raise CancelledError()
#     443 elif self._state == FINISHED:
# --> 444     return self.__get_result()
#     445 else:
#     446     raise TimeoutError()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\concurrent\futures\_base.py:389, in Future.__get_result(self)
#     387 if self._exception:
#     388     try:
# --> 389         raise self._exception
#     390     finally:
#     391         # Break a reference cycle with the exception in self._exception
#     392         self = None
#
# File ~\AppData\Local\Programs\Python\Python38\lib\concurrent\futures\thread.py:57, in _WorkItem.run(self)
#      54     return
#      56 try:
# ---> 57     result = self.fn(*self.args, **self.kwargs)
#      58 except BaseException as exc:
#      59     self.future.set_exception(exc)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\beta_rec\utils\common_util.py:232, in timeit.<locals>.wrapper(*args, **kw)
#     229 @wraps(method)
#     230 def wrapper(*args, **kw):
#     231     ts = time.time()
# --> 232     result = method(*args, **kw)
#     233     te = time.time()
#     234     if "log_time" in kw:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\beta_rec\core\eval_engine.py:174, in test_eval_worker(testEngine, eval_data_df, prediction)
#     172 lock_test_eval.release()
#     173 testEngine.n_worker -= 1
# --> 174 save_mode = config["save_mode"]
#     175 if save_mode == "per_user":
#     176     rating_pre_df = eval_data_df.drop(columns=["col_timestamp"])
#
# KeyError: 'save_mode'

# %% [markdown]
# The results are displayed in the form of a JSON file below.

# %%
temporal_result
